# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
ds00 = xr.load_dataset('200_geo_em_LIDAR_noveg.nc')
ds01 = xr.load_dataset('200_geo_em_LIDAR_noveg_modified.nc')

# %%
ds01['URB_PARAM'][0,117:].sum(axis=0).plot()

# %%
ds00['URB_PARAM'][0,120].plot()
plt.figure()
ds01['URB_PARAM'][0,120].plot()

# %%
ds1 = xr.load_dataset('geo_em_test_madrid_URB_PARAM_FRC_URB2D.nc')

# %%
ds1['URB_PARAM'][0,93].plot()

# %%
ds1['FRC_URB2D'].plot()

# %%
(ds1['URB_PARAM'][0,91]-ds['URB_PARAM'][0,91]).plot()

# %%
ds0 = xr.load_dataset('geo_em_valencia_test1_modified.nc')

# %%
ds0['URB_PARAM'][0,117:].sum(axis=0).plot()

# %%
(ds['FRC_URB2D'] - ds0['FRC_URB2D']).plot()
