# %%
import xarray as xr

# %%
ds = xr.load_dataset('geo_em_test_madrid_modified.nc')

ds['FRC_URB2D'].plot()

# %%
ds0 = xr.load_dataset('geo_em_valencia_test.nc')

ds0['FRC_URB2D'].plot()

# %%
(ds['FRC_URB2D'] - ds0['FRC_URB2D']).plot()
